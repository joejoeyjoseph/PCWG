# %%
import pcwg03_config as pc
import pcwg03_read_data as prd
import pcwg03_convert_df as pcd
import pcwg03_plot as pp
import pcwg03_energy_fraction as pef
import pcwg03_slice_df as psd

import importlib

# package = [pc, prd, pcd, pp, pef, psd]

# for x in package:
#     importlib.reload(x)
    
import pcwg03_load_data as pld
importlib.reload(pld)

# %matplotlib inline
# Out:
# metadata pkl file exists; loading pkl file directly!
# error pkl file exists; loading pkl file directly!
# extra_error pkl file exists; loading pkl file directly!
# data files with baseline bin error per bin energy exceed 1% are:
# 3704     387f1955ba7504fde0ddb2dced2007181736e811
# 12260    91267cfb07774528dd56ccf267f7eff8dc8af831
# 13376    9cff170a5d30b8e5bffcdac3d8dbedc54dc5075d
# Name: file_name, dtype: object
# a total of 3 files contain bad data
# removing 3 files in base_bin_e
# removing 3 files in den_turb_bin_e
# removing 3 files in den_2dpdm_bin_e
# removing 3 files in den_augturb_bin_e
# removing 3 files in den_3dpdm_bin_e
# removing 3 files in base_total_e
# removing 3 files in den_turb_total_e
# removing 3 files in den_2dpdm_total_e
# removing 3 files in den_augturb_total_e
# removing 3 files in den_3dpdm_total_e
# removing 0 files in den_rews_svturb_bin_e
# removing 0 files in den_rews_sv_bin_e
# removing 0 files in den_raws_sv_bin_e
# ...

# %%
importlib.reload(pp)
pp.plot_group_meta_hist()

# %%
pp.loop_meta_hist()

# %%
importlib.reload(pp)
pp.plot_map()

# %%
importlib.reload(pp)
pp.plot_NME_hist()
# Out:
# error pkl file exists; loading pkl file directly!

# %%
importlib.reload(pp)
pp.plot_wsti_nme_box()

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
importlib.reload(pp)

# %%
import os
import glob

data_file_path = '/Users/jlee/Documents/GitHub/PCWG_Share_03/data_03/data/'

# code directory
py_file_path = os.getcwd()
# put generated plots near code
out_plot_path = py_file_path+'/plots/'

data_file = glob.glob(data_file_path+'*.xls')

sub_df = pcd.get_submission_df(data_file)
meta_df = pcd.get_metadata_df(data_file)

# QC 
error_df, extra_error_df = pcd.filter_base_bin_nme(pcd.get_error_df_dict(data_file), 
                                                   pcd.get_extra_error_df_dict(data_file))
# Out:
# submission pkl file exists; loading pkl file directly!
# metadata pkl file exists; loading pkl file directly!
# error pkl file exists; loading pkl file directly!
# extra_error pkl file exists; loading pkl file directly!
# data files with baseline bin error per bin energy exceed 1% are:
# 3704     387f1955ba7504fde0ddb2dced2007181736e811
# 12260    91267cfb07774528dd56ccf267f7eff8dc8af831
# 13376    9cff170a5d30b8e5bffcdac3d8dbedc54dc5075d
# Name: file_name, dtype: object
# a total of 3 files contain bad data
# removing 3 files in base_bin_e
# removing 3 files in den_turb_bin_e
# removing 3 files in den_2dpdm_bin_e
# removing 3 files in den_augturb_bin_e
# removing 3 files in den_3dpdm_bin_e
# removing 3 files in base_total_e
# removing 3 files in den_turb_total_e
# removing 3 files in den_2dpdm_total_e
# removing 3 files in den_augturb_total_e
# removing 3 files in den_3dpdm_total_e
# removing 0 files in den_rews_svturb_bin_e
# removing 0 files in den_rews_sv_bin_e
# ...

# %%
pp.plot_wsti_energy_fraction_box()
# Out:
# 4 by_ws_ti files are problematic

# %%
pp.plot_outws_energy_fraction_box()
# Out:
# none of the files are problematic

# %%
df = psd.get_wsti_nme_stat()
